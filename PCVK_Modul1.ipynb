# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanessss20/PCVK_Ganjil_2024/blob/main/PCVK_Modul1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Library
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://th.bing.com/th/id/OIP.Vx6AuThvkOR3tWSzGS3FbAAAAA?w=400&h=400&rs=1&pid=ImgDetMain",
        "https://iv1.lisimg.com/image/21408349/740full-zero-two.jpg",
        "https://static.wikia.nocookie.net/plastic-memories/images/0/0f/HappyIsla.jpg/revision/latest/scale-to-width-down/1000?cb=20170909115549"
        ]

for url in urls:
  image = io.imread(url)                            #Read Image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #Resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #Convert image to RGB
  final_frame = cv.hconcat((image,image_2))         #Concatenate image
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>
# <PIL.Image.Image image mode=RGB size=740x370>
# <PIL.Image.Image image mode=RGB size=1000x282>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  282  x  500
# <PIL.Image.Image image mode=RGB size=500x282>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x282>

# %% [markdown]
# # **PERTANYAAN** <br>
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# > Google Colab digunakan karena mudah diakses, menyediakan lingkungan siap pakai tanpa perlu instalasi lokal, mendukung GPU untuk komputasi berat, serta memungkinkan kolaborasi dan eksekusi kode secara interaktif.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# - OpenCV (cv2): Untuk operasi pengolahan gambar seperti membaca, mengubah ukuran, dan mengonversi warna gambar.
# - NumPy: Untuk manipulasi array multidimensi yang mewakili gambar.
# - Matplotlib: Untuk visualisasi dan menampilkan gambar dengan anotasi.
# - Pillow (PIL): Untuk membuka dan mengonversi format gambar yang berbeda.<br><br>
#
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut:
# `image = cv.resize(image, (0,0), fx=0.5, fy=0.5)`<br>
# > Kode ini mengubah ukuran gambar menjadi setengah dari ukuran aslinya dengan menggunakan faktor skala 0.5 untuk sumbu horizontal (fx) dan vertikal (fy).
#
# 4. Perhatikan potongan kode progam berikut: <br>
# `for y in range (lebar):`<br>
#   `image_3[int((tinggi)/2),y] = [255,255,255]`
# > Kode ini menggambar garis putih horizontal di tengah gambar image_3 dengan mengubah semua piksel pada baris tengah gambar menjadi warna putih.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# > Resolusi gambar ditentukan oleh jumlah piksel; semakin banyak piksel, semakin tinggi resolusinya, yang menghasilkan gambar lebih detail, sedangkan resolusi rendah menghasilkan gambar yang lebih buram atau pixelated.

# %% [markdown]
# # **TUGAS**

# %%
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_4[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=1000x282>

# %%
tinggi, lebar, _ = image.shape
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for i in range(lebar):
    y = int((i * tinggi) / lebar)
    image_5[y, i] = [255, 255, 255]

for i in range(lebar):
    y = tinggi - 1 - int((i * tinggi) / lebar)
    image_5[y, i] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x282>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_6 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(20, (int((lebar)/2))):
  image_6[int((tinggi)/2), x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_6))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x282>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_7 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range((int((lebar)/4)), (int((lebar)/2))):
  for x in range((int((lebar)/4)), (int((lebar)/2))):
    image_7[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_7))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x282>
